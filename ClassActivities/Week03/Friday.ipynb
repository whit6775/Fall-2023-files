# %% [markdown]
# # Friday, September 8
# ## Announcements and Reminders
# - Programming Assignment 1... redo it?
# - Chapter 4 Exercises due tonight
# - Chapter 5 Reading due Monday
#
# ## Questions:

# %% [markdown]
# ## Activity: COWABUNGA!!! 🐢 🐢 🐢 🐢 🐀
#
# Start by installing the ColabTurtlePlus library by executing the code below.  This is only necessary for working in a jupyter notebook, and must be done once each time you start up a new notebook.

# %% [markdown]
# The program below is written to create Tommy the turtle in his own sandy environment.  Note that we are *importing* a module called `ipyturtle3`.  This doesn't come with python, but was installed in your codespace by running `pip install -r requirements.txt` when the codespace was created.  If the code below throws an error, you can fix this by opening a terminal and using that command (or running `pip install ipyturtle3`).

# %%
# from ColabTurtlePlus.Turtle import *  # use the turtle library
import ipyturtle3 as turtle
from ipyturtle3 import hold_canvas
myCanvas=turtle.Canvas(width=800,height=500)
display(myCanvas)
sandbox=turtle.TurtleScreen(myCanvas)
sandbox.clear()# clears the screen before each run
sandbox.bgcolor("sandybrown")  # sets the background color

Tommy = turtle.Turtle(sandbox)  # create a Turtle object named Tommy
Tommy.shape("turtle")  # make Tommy look like a turtle
Tommy.color("blue", "green")  # make Tommy a green turtle with blue trace

# %% [markdown]
# Tommy is quite talented; I can have him write almost anything in his space! Run the program below to see what Tommy says.

# %%
### SETUP CODE ###
sandbox.clear()
sandbox.bgcolor("sandybrown") 
Tommy = turtle.Turtle(sandbox) 
Tommy.shape("turtle") 
Tommy.color("blue", "green") 
### END SETUP CODE ###

Tommy.penup()
Tommy.goto(-350,200)
Tommy.pendown()
Tommy.right(90)
Tommy.forward(100)
Tommy.backward(50)
Tommy.left(90)
Tommy.forward(50)
Tommy.left(90)
Tommy.forward(50)
Tommy.backward(100)
Tommy.penup()
Tommy.goto(-250,200)
Tommy.pendown()
Tommy.right(90)
Tommy.forward(50)
Tommy.backward(50)
Tommy.right(90)
Tommy.forward(50)
Tommy.left(90)
Tommy.forward(50)
Tommy.backward(50)
Tommy.right(90)
Tommy.forward(50)
Tommy.left(90)
Tommy.forward(50)
Tommy.penup()
Tommy.goto(-150,200)
Tommy.pendown()
Tommy.right(90)
Tommy.forward(100)
Tommy.left(90)
Tommy.forward(50)
Tommy.penup()
Tommy.goto(-50,200)
Tommy.pendown()
Tommy.right(90)
Tommy.forward(100)
Tommy.left(90)
Tommy.forward(50)
Tommy.penup()
Tommy.goto(50,200)
Tommy.pendown()
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(100)
Tommy.right(90)
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(100)
Tommy.penup()
Tommy.goto(-350,0)
Tommy.pendown()
Tommy.backward(100)
Tommy.right(90)
Tommy.forward(50)
Tommy.left(90)
Tommy.forward(50)
Tommy.backward(50)
Tommy.right(90)
Tommy.forward(50)
Tommy.left(90)
Tommy.forward(100)
Tommy.penup()
Tommy.goto(-200,0)
Tommy.pendown()
Tommy.right(90)
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(100)
Tommy.right(90)
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(100)
Tommy.penup()
Tommy.goto(-100,0)
Tommy.pendown()
Tommy.right(90)
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(50)
Tommy.right(90)
Tommy.forward(50)
Tommy.backward(100)
Tommy.forward(50)
Tommy.goto(-50,-100)
Tommy.penup()
Tommy.goto(0,0)
Tommy.pendown()
Tommy.backward(100)
Tommy.right(90)
Tommy.forward(50)
Tommy.penup()
Tommy.goto(100,0)
Tommy.pendown()
Tommy.goto(150,-25)
Tommy.goto(150,-75)
Tommy.goto(100,-100)
Tommy.left(90)
Tommy.forward(100)

# %% [markdown]
# Below are several *methods* (which is what we call a function defined for a particular type of object, in this case, a turtle).  These can help our turtles navigate their digital domains. To call a method, we employ dot notation: If I wanted my turtle, Tommy, to turn 90 degrees clockwise (to the right), I would use Tommy.right(90).
#
# ![2022-09-10.png](data:image/png;base64,...)

# %% [markdown]
# Use these methods to help your turtle navigate the maze below to get to the red ball of food, without going through any walls.
#
# Note: The screen that our turtles live in is 800 x 600 units: The center of the screen is the point (0,0), the far right is (400,0), the far left is (-400,0), the top is (0,300), and the bottom is (0,-300)

# %%
####### DO NOT EDIT ###########
myCanvas=turtle.Canvas(width=800,height=600)
display(myCanvas)
sandbox=turtle.TurtleScreen(myCanvas)
sandbox.clear()
sandbox.bgcolor("sandybrown")  
food = turtle.Turtle(sandbox)
food.penup()
food.speed(10000)
food.shape('circle')
food.color('red')
food.goto(300,250)
wall1 = turtle.Turtle(sandbox)
wall1.penup()
wall1.speed(10000000)
wall1.goto(-400,-250)
wall1.pendown()
wall1.goto(-125,-250)
wall1.goto(-125,200)
wall1.goto(100,200)
wall1.goto(-50,200)
wall1.goto(150,200)
wall1.goto(150,25)
wall1.goto(275,25)
wall1.goto(275,300)
wall2 = turtle.Turtle(sandbox)
wall2.penup()
wall2.speed(10000000)
wall2.goto(-400,-300)
wall2.pendown()
wall2.goto(-75,-300)
wall2.goto(-75,150)
wall2.goto(100,150)
wall2.goto(100,-25)
wall2.goto(325,-25)
wall2.goto(325,300)
######## END DO NOT EDIT ###########

# You can change code from this point down.  You can edit the name and shape and color of your turtle if you like.
Tommy = turtle.Turtle(sandbox)
Tommy.penup() # Change name only on this line
Tommy.speed(1000000)
Tommy.goto(-375,-275) # Change name only on this line
Tommy.speed(1)
Tommy.pendown() # Change name only on this line
Tommy.shape("turtle")
Tommy.color("blue", "green")

# %%
# Guide your turtle above by writing code below.
Tommy.forward()

# %% [markdown]
# Let's try something else.
#
# In the code cell below, have your turtle draw a square.

# %%
### CREATE NEW CANVAS ###
myCanvas=turtle.Canvas(width=800,height=500)
display(myCanvas)
sandbox=turtle.TurtleScreen(myCanvas)
sandbox.clear()# clears the screen before each run
sandbox.bgcolor("sandybrown")  # sets the background color according to R,G,B values
Tommy = turtle.Turtle(sandbox)
Tommy.shape("turtle")
Tommy.color("blue", "green")
### END CREATE NEW CANVAS ###

# %% [markdown]
# Great, our turtles can draw a square! But what if we wanted to have our turtles draw multiple squares, say, in a quilt pattern?  Like this:
#
# ![2022-09-12.png](data:image/png;base64,...)
#
# We don't want to have to copy, paste, and run our square code for every square! Instead, ***create a function that takes coordinates (x,y) and a side length as inputs, and creates a square as output***. Then, call the funtion multiple times to draw the pattern described above.

# %%
### CREATE NEW CANVAS ###
myCanvas=turtle.Canvas(width=800,height=500)
display(myCanvas)
sandbox=turtle.TurtleScreen(myCanvas)
sandbox.clear()
sandbox.bgcolor("sandybrown")  
Tommy = turtle.Turtle(sandbox)
Tommy.shape("turtle")
Tommy.color("blue", "green")
### END CREATE NEW CANVAS ###

### DEFINE SQUARE FUNCTION ###


### CALL FUNCTION ###

# %% [markdown]
# We might want to be creative and have our turtles create other shapes or images, but that could be tedious (consider, for example, the program written just for Tommy to say 'HELLO WORLD'). To do this, it might be easier to use a recursive function and introduce a count variable.  The function will just draw one side of the square, and then repeat itself until the count variable tells it to stop.
#
# Using our knowledge of recursive functions, let's write a program that will take a side length as input and draw a square.

# %%
### CREATE NEW CANVAS ###
myCanvas=turtle.Canvas(width=800,height=500)
display(myCanvas)
sandbox=turtle.TurtleScreen(myCanvas)
sandbox.clear()
sandbox.bgcolor("sandybrown") 
Tommy = turtle.Turtle(sandbox)
Tommy.shape("turtle")
Tommy.color("blue", "green")
### END CREATE NEW CANVAS ###

# %% [markdown]
# What if we want our turtles to be able to create any shape we ask it to? For now, let's limit ourselves just to regular polygons. ***Write a function that will take a number of sides as one input and a side length as a second input*** so that our turtles will draw a regular shape with that many sides as our output.

# %%
### CREATE NEW CANVAS ###
myCanvas=turtle.Canvas(width=800,height=500)
display(myCanvas)
sandbox=turtle.TurtleScreen(myCanvas)
sandbox.clear()
sandbox.bgcolor("sandybrown") 
Tommy = turtle.Turtle(sandbox)
Tommy.shape("turtle")
Tommy.color("blue", "green")
### END CREATE NEW CANVAS ###
